# %% [markdown]
# ### 시장분석
# * 유통산업분석

# %% [markdown]
# ### 신세계 주가 분석
# * 목표

# %% [markdown]
# ### 신세계 기업개요
# * 개요

# %% [markdown]
# * 대표 :

# %% [markdown]
# ### 투자 리포트
#  * 개요

# %% [markdown]
# ### 산업개요

# %% [markdown]
# # 금융분석
#  * 일일 주가분석
#     - url:https://finance.naver.com/item/sise_day.nhn?code=004170&page=2

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup as bsp
import matplotlib as mpl
import matplotlib.pyplot as plt
import sqlite3

# %%
code='004170'
pgno=2
url='https://finance.naver.com/item/sise_day.nhn?code={0}&page={1}'
tgurl=url.format(code,pgno)
tgurl
# Out:
# 'https://finance.naver.com/item/sise_day.nhn?code=004170&page=2'

# %%
def getPage(tgurl):
    headerdata = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36',
    }
    src=requests.get(tgurl,headers=headerdata)
    cont=src.content.strip()
    html=bsp(cont, 'html.parser')
    tgts=html.select("table.type2 tr")
    stocklist=[]
    for t in tgts:
        sday=t.select(".gray03")
        tds=t.select('td')
        if(sday):
            tkey=sday[0].text.replace('.','')
            tday=sday[0].text.replace('.','-')
            topen=tds[3].text.replace(',','')
            thigh=tds[4].text.replace(',','')
            tlow=tds[5].text.replace(',','')
            tclose=tds[1].text.replace(',','')
            tvol=tds[6].text.replace(',','')
            stocklist.append([tday,topen,thigh,tlow,tclose,tvol,tkey])
    return stocklist

# %%
dbname='./navernews.db'
def dataprs(d=[]):
    with sqlite3.connect(dbname) as conn:
        cur=conn.cursor()
        if d :
            sql='select skey from stockp where skey={}'.format(d[6])
            checkkey=cur.execute(sql).fetchall()
            if checkkey:
                print("중복있음:",d[6])
            else:
                sql="insert into stockp (sday,sopen,shigh,slow,sclose,svol,skey) values(?,?,?,?,?,?,?)"
                cur.execute(sql,d)
                print('입력완료 - ',d[0])
        else:
            sql='select * from stockp'
            result=cur.execute(sql).fetchall()
            print(result)

# %%
for i in range(1,90):
    tgurl=url.format(code,i)
    slist=getPage(tgurl)
    for s in slist:
        dataprs(s)
# Out:
# 입력완료 -  2021-04-02
# 입력완료 -  2021-04-01
# 입력완료 -  2021-03-31
# 입력완료 -  2021-03-30
# 입력완료 -  2021-03-29
# 입력완료 -  2021-03-26
# 입력완료 -  2021-03-25
# 입력완료 -  2021-03-24
# 입력완료 -  2021-03-23
# 입력완료 -  2021-03-22
# 입력완료 -  2021-03-19
# 입력완료 -  2021-03-18
# 입력완료 -  2021-03-17
# 입력완료 -  2021-03-16
# 입력완료 -  2021-03-15
# 입력완료 -  2021-03-12
# 입력완료 -  2021-03-11
# 입력완료 -  2021-03-10
# 입력완료 -  2021-03-09
# 입력완료 -  2021-03-08
# 입력완료 -  2021-03-05
# 입력완료 -  2021-03-04
# 입력완료 -  2021-03-03
# 입력완료 -  2021-03-02
# 입력완료 -  2021-02-26
# 입력완료 -  2021-02-25
# 입력완료 -  2021-02-24
# 입력완료 -  2021-02-23
# 입력완료 -  2021-02-22
# 입력완료 -  2021-02-19
# 입력완료 -  2021-02-18
# 입력완료 -  2021-02-17
# 입력완료 -  2021-02-16
# 입력완료 -  2021-02-15
# 입력완료 -  2021-02-10
# 입력완료 -  2021-02-09
# 입력완료 -  2021-02-08
# 입력완료 -  2021-02-05
# 입력완료 -  2021-02-04
# 입력완료 -  2021-02-03
# 입력완료 -  2021-02-02
# 입력완료 -  2021-02-01
# 입력완료 -  2021-01-29
# 입력완료 -  2021-01-28
# 입력완료 -  2021-01-27
# 입력완료 -  2021-01-26
# 입력완료 -  2021-01-25
# 입력완료 -  2021-01-22
# 입력완료 -  2021-01-21
# 입력완료 -  2021-01-20
# 입력완료 -  2021-01-19
# 입력완료 -  2021-01-18
# 입력완료 -  2021-01-15
# 입력완료 -  2021-01-14
# 입력완료 -  2021-01-13
# 입력완료 -  2021-01-12
# 입력완료 -  2021-01-11
# 입력완료 -  2021-01-08
# 입력완료 -  2021-01-07
# 입력완료 -  2021-01-06
# 입력완료 -  2021-01-05
# 입력완료 -  2021-01-04
# 입력완료 -  2020-12-30
# 입력완료 -  2020-12-29
# 입력완료 -  2020-12-28
# 입력완료 -  2020-12-24
# 입력완료 -  2020-12-23
# 입력완료 -  2020-12-22
# 입력완료 -  2020-12-21
# 입력완료 -  2020-12-18
# 입력완료 -  2020-12-17
# 입력완료 -  2020-12-16
# 입력완료 -  2020-12-15
# 입력완료 -  2020-12-14
# 입력완료 -  2020-12-11
# 입력완료 -  2020-12-10
# 입력완료 -  2020-12-09
# 입력완료 -  2020-12-08
# 입력완료 -  2020-12-07
# 입력완료 -  2020-12-04
# 입력완료 -  2020-12-03
# 입력완료 -  2020-12-02
# 입력완료 -  2020-12-01
# 입력완료 -  2020-11-30
# 입력완료 -  2020-11-27
# 입력완료 -  2020-11-26
# 입력완료 -  2020-11-25
# 입력완료 -  2020-11-24
# 입력완료 -  2020-11-23
# 입력완료 -  2020-11-20
# 입력완료 -  2020-11-19
# 입력완료 -  2020-11-18
# 입력완료 -  2020-11-17
# 입력완료 -  2020-11-16
# 입력완료 -  2020-11-13
# 입력완료 -  2020-11-12
# 입력완료 -  2020-11-11
# 입력완료 -  2020-11-10
# 입력완료 -  2020-11-09
# 입력완료 -  2020-11-06
# 입력완료 -  2020-11-05
# 입력완료 -  2020-11-04
# 입력완료 -  2020-11-03
# 입력완료 -  2020-11-02
# 입력완료 -  2020-10-30
# 입력완료 -  2020-10-29
# 입력완료 -  2020-10-28
# 입력완료 -  2020-10-27
# 입력완료 -  2020-10-26
# 입력완료 -  2020-10-23
# 입력완료 -  2020-10-22
# 입력완료 -  2020-10-21
# 입력완료 -  2020-10-20
# 입력완료 -  2020-10-19
# 입력완료 -  2020-10-16
# 입력완료 -  2020-10-15
# 입력완료 -  2020-10-14
# 입력완료 -  2020-10-13
# 입력완료 -  2020-10-12
# 입력완료 -  2020-10-08
# 입력완료 -  2020-10-07
# 입력완료 -  2020-10-06
# 입력완료 -  2020-10-05
# 입력완료 -  2020-09-29
# 입력완료 -  2020-09-28
# 입력완료 -  2020-09-25
# 입력완료 -  2020-09-24
# 입력완료 -  2020-09-23
# 입력완료 -  2020-09-22
# 입력완료 -  2020-09-21
# 입력완료 -  2020-09-18
# 입력완료 -  2020-09-17
# 입력완료 -  2020-09-16
# 입력완료 -  2020-09-15
# 입력완료 -  2020-09-14
# 입력완료 -  2020-09-11
# 입력완료 -  2020-09-10
# 입력완료 -  2020-09-09
# 입력완료 -  2020-09-08
# 입력완료 -  2020-09-07
# 입력완료 -  2020-09-04
# 입력완료 -  2020-09-03
# 입력완료 -  2020-09-02
# 입력완료 -  2020-09-01
# 입력완료 -  2020-08-31
# 입력완료 -  2020-08-28
# 입력완료 -  2020-08-27
# 입력완료 -  2020-08-26
# 입력완료 -  2020-08-25
# 입력완료 -  2020-08-24
# 입력완료 -  2020-08-21
# 입력완료 -  2020-08-20
# 입력완료 -  2020-08-19
# 입력완료 -  2020-08-18
# 입력완료 -  2020-08-14
# 입력완료 -  2020-08-13
# 입력완료 -  2020-08-12
# 입력완료 -  2020-08-11
# 입력완료 -  2020-08-10
# 입력완료 -  2020-08-07
# 입력완료 -  2020-08-06
# 입력완료 -  2020-08-05
# 입력완료 -  2020-08-04
# 입력완료 -  2020-08-03
# 입력완료 -  2020-07-31
# 입력완료 -  2020-07-30
# 입력완료 -  2020-07-29
# 입력완료 -  2020-07-28
# 입력완료 -  2020-07-27
# 입력완료 -  2020-07-24
# 입력완료 -  2020-07-23
# 입력완료 -  2020-07-22
# 입력완료 -  2020-07-21
# 입력완료 -  2020-07-20
# 입력완료 -  2020-07-17
# 입력완료 -  2020-07-16
# 입력완료 -  2020-07-15
# 입력완료 -  2020-07-14
# 입력완료 -  2020-07-13
# 입력완료 -  2020-07-10
# 입력완료 -  2020-07-09
# 입력완료 -  2020-07-08
# 입력완료 -  2020-07-07
# 입력완료 -  2020-07-06
# 입력완료 -  2020-07-03
# 입력완료 -  2020-07-02
# 입력완료 -  2020-07-01
# 입력완료 -  2020-06-30
# 입력완료 -  2020-06-29
# 입력완료 -  2020-06-26
# 입력완료 -  2020-06-25
# 입력완료 -  2020-06-24
# 입력완료 -  2020-06-23
# 입력완료 -  2020-06-22
# 입력완료 -  2020-06-19
# 입력완료 -  2020-06-18
# 입력완료 -  2020-06-17
# 입력완료 -  2020-06-16
# 입력완료 -  2020-06-15
# 입력완료 -  2020-06-12
# 입력완료 -  2020-06-11
# 입력완료 -  2020-06-10
# 입력완료 -  2020-06-09
# 입력완료 -  2020-06-08
# 입력완료 -  2020-06-05
# 입력완료 -  2020-06-04
# 입력완료 -  2020-06-03
# 입력완료 -  2020-06-02
# 입력완료 -  2020-06-01
# 입력완료 -  2020-05-29
# 입력완료 -  2020-05-28
# 입력완료 -  2020-05-27
# 입력완료 -  2020-05-26
# 입력완료 -  2020-05-25
# 입력완료 -  2020-05-22
# 입력완료 -  2020-05-21
# 입력완료 -  2020-05-20
# 입력완료 -  2020-05-19
# 입력완료 -  2020-05-18
# 입력완료 -  2020-05-15
# 입력완료 -  2020-05-14
# 입력완료 -  2020-05-13
# 입력완료 -  2020-05-12
# 입력완료 -  2020-05-11
# 입력완료 -  2020-05-08
# 입력완료 -  2020-05-07
# 입력완료 -  2020-05-06
# 입력완료 -  2020-05-04
# 입력완료 -  2020-04-29
# 입력완료 -  2020-04-28
# 입력완료 -  2020-04-27
# 입력완료 -  2020-04-24
# 입력완료 -  2020-04-23
# 입력완료 -  2020-04-22
# 입력완료 -  2020-04-21
# 입력완료 -  2020-04-20
# 입력완료 -  2020-04-17
# 입력완료 -  2020-04-16
# 입력완료 -  2020-04-14
# 입력완료 -  2020-04-13
# 입력완료 -  2020-04-10
# 입력완료 -  2020-04-09
# 입력완료 -  2020-04-08
# 입력완료 -  2020-04-07
# 입력완료 -  2020-04-06
# 입력완료 -  2020-04-03
# 입력완료 -  2020-04-02
# 입력완료 -  2020-04-01
# 입력완료 -  2020-03-31
# 입력완료 -  2020-03-30
# 입력완료 -  2020-03-27
# 입력완료 -  2020-03-26
# 입력완료 -  2020-03-25
# 입력완료 -  2020-03-24
# 입력완료 -  2020-03-23
# 입력완료 -  2020-03-20
# 입력완료 -  2020-03-19
# 입력완료 -  2020-03-18
# 입력완료 -  2020-03-17
# 입력완료 -  2020-03-16
# 입력완료 -  2020-03-13
# 입력완료 -  2020-03-12
# 입력완료 -  2020-03-11
# 입력완료 -  2020-03-10
# 입력완료 -  2020-03-09
# 입력완료 -  2020-03-06
# 입력완료 -  2020-03-05
# 입력완료 -  2020-03-04
# 입력완료 -  2020-03-03
# 입력완료 -  2020-03-02
# 입력완료 -  2020-02-28
# 입력완료 -  2020-02-27
# 입력완료 -  2020-02-26
# 입력완료 -  2020-02-25
# 입력완료 -  2020-02-24
# 입력완료 -  2020-02-21
# 입력완료 -  2020-02-20
# 입력완료 -  2020-02-19
# 입력완료 -  2020-02-18
# 입력완료 -  2020-02-17
# 입력완료 -  2020-02-14
# 입력완료 -  2020-02-13
# 입력완료 -  2020-02-12
# 입력완료 -  2020-02-11
# 입력완료 -  2020-02-10
# 입력완료 -  2020-02-07
# 입력완료 -  2020-02-06
# 입력완료 -  2020-02-05
# 입력완료 -  2020-02-04
# 입력완료 -  2020-02-03
# 입력완료 -  2020-01-31
# 입력완료 -  2020-01-30
# 입력완료 -  2020-01-29
# 입력완료 -  2020-01-28
# 입력완료 -  2020-01-23
# 입력완료 -  2020-01-22
# 입력완료 -  2020-01-21
# 입력완료 -  2020-01-20
# 입력완료 -  2020-01-17
# 입력완료 -  2020-01-16
# 입력완료 -  2020-01-15
# 입력완료 -  2020-01-14
# 입력완료 -  2020-01-13
# 입력완료 -  2020-01-10
# 입력완료 -  2020-01-09
# 입력완료 -  2020-01-08
# 입력완료 -  2020-01-07
# 입력완료 -  2020-01-06
# 입력완료 -  2020-01-03
# 입력완료 -  2020-01-02
# 입력완료 -  2019-12-30
# 입력완료 -  2019-12-27
# 입력완료 -  2019-12-26
# 입력완료 -  2019-12-24
# 입력완료 -  2019-12-23
# 입력완료 -  2019-12-20
# 입력완료 -  2019-12-19
# 입력완료 -  2019-12-18
# 입력완료 -  2019-12-17
# 입력완료 -  2019-12-16
# 입력완료 -  2019-12-13
# 입력완료 -  2019-12-12
# 입력완료 -  2019-12-11
# 입력완료 -  2019-12-10
# 입력완료 -  2019-12-09
# 입력완료 -  2019-12-06
# 입력완료 -  2019-12-05
# 입력완료 -  2019-12-04
# 입력완료 -  2019-12-03
# 입력완료 -  2019-12-02
# 입력완료 -  2019-11-29
# 입력완료 -  2019-11-28
# 입력완료 -  2019-11-27
# 입력완료 -  2019-11-26
# 입력완료 -  2019-11-25
# 입력완료 -  2019-11-22
# 입력완료 -  2019-11-21
# 입력완료 -  2019-11-20
# 입력완료 -  2019-11-19
# 입력완료 -  2019-11-18
# 입력완료 -  2019-11-15
# 입력완료 -  2019-11-14
# 입력완료 -  2019-11-13
# 입력완료 -  2019-11-12
# 입력완료 -  2019-11-11
# 입력완료 -  2019-11-08
# 입력완료 -  2019-11-07
# 입력완료 -  2019-11-06
# 입력완료 -  2019-11-05
# 입력완료 -  2019-11-04
# 입력완료 -  2019-11-01
# 입력완료 -  2019-10-31
# 입력완료 -  2019-10-30
# 입력완료 -  2019-10-29
# 입력완료 -  2019-10-28
# 입력완료 -  2019-10-25
# 입력완료 -  2019-10-24
# 입력완료 -  2019-10-23
# 입력완료 -  2019-10-22
# 입력완료 -  2019-10-21
# 입력완료 -  2019-10-18
# 입력완료 -  2019-10-17
# 입력완료 -  2019-10-16
# 입력완료 -  2019-10-15
# 입력완료 -  2019-10-14
# 입력완료 -  2019-10-11
# 입력완료 -  2019-10-10
# 입력완료 -  2019-10-08
# 입력완료 -  2019-10-07
# 입력완료 -  2019-10-04
# 입력완료 -  2019-10-02
# 입력완료 -  2019-10-01
# 입력완료 -  2019-09-30
# 입력완료 -  2019-09-27
# 입력완료 -  2019-09-26
# 입력완료 -  2019-09-25
# 입력완료 -  2019-09-24
# 입력완료 -  2019-09-23
# 입력완료 -  2019-09-20
# 입력완료 -  2019-09-19
# 입력완료 -  2019-09-18
# 입력완료 -  2019-09-17
# 입력완료 -  2019-09-16
# 입력완료 -  2019-09-11
# 입력완료 -  2019-09-10
# 입력완료 -  2019-09-09
# 입력완료 -  2019-09-06
# 입력완료 -  2019-09-05
# 입력완료 -  2019-09-04
# 입력완료 -  2019-09-03
# 입력완료 -  2019-09-02
# 입력완료 -  2019-08-30
# 입력완료 -  2019-08-29
# 입력완료 -  2019-08-28
# 입력완료 -  2019-08-27
# 입력완료 -  2019-08-26
# 입력완료 -  2019-08-23
# 입력완료 -  2019-08-22
# 입력완료 -  2019-08-21
# 입력완료 -  2019-08-20
# 입력완료 -  2019-08-19
# 입력완료 -  2019-08-16
# 입력완료 -  2019-08-14
# 입력완료 -  2019-08-13
# 입력완료 -  2019-08-12
# 입력완료 -  2019-08-09
# 입력완료 -  2019-08-08
# 입력완료 -  2019-08-07
# 입력완료 -  2019-08-06
# 입력완료 -  2019-08-05
# 입력완료 -  2019-08-02
# 입력완료 -  2019-08-01
# 입력완료 -  2019-07-31
# 입력완료 -  2019-07-30
# 입력완료 -  2019-07-29
# 입력완료 -  2019-07-26
# 입력완료 -  2019-07-25
# 입력완료 -  2019-07-24
# 입력완료 -  2019-07-23
# 입력완료 -  2019-07-22
# 입력완료 -  2019-07-19
# 입력완료 -  2019-07-18
# 입력완료 -  2019-07-17
# 입력완료 -  2019-07-16
# 입력완료 -  2019-07-15
# 입력완료 -  2019-07-12
# 입력완료 -  2019-07-11
# 입력완료 -  2019-07-10
# 입력완료 -  2019-07-09
# 입력완료 -  2019-07-08
# 입력완료 -  2019-07-05
# 입력완료 -  2019-07-04
# 입력완료 -  2019-07-03
# 입력완료 -  2019-07-02
# 입력완료 -  2019-07-01
# 입력완료 -  2019-06-28
# 입력완료 -  2019-06-27
# 입력완료 -  2019-06-26
# 입력완료 -  2019-06-25
# 입력완료 -  2019-06-24
# 입력완료 -  2019-06-21
# 입력완료 -  2019-06-20
# 입력완료 -  2019-06-19
# 입력완료 -  2019-06-18
# 입력완료 -  2019-06-17
# 입력완료 -  2019-06-14
# 입력완료 -  2019-06-13
# 입력완료 -  2019-06-12
# 입력완료 -  2019-06-11
# 입력완료 -  2019-06-10
# 입력완료 -  2019-06-07
# 입력완료 -  2019-06-05
# 입력완료 -  2019-06-04
# 입력완료 -  2019-06-03
# 입력완료 -  2019-05-31
# 입력완료 -  2019-05-30
# 입력완료 -  2019-05-29
# 입력완료 -  2019-05-28
# 입력완료 -  2019-05-27
# 입력완료 -  2019-05-24
# 입력완료 -  2019-05-23
# 입력완료 -  2019-05-22
# 입력완료 -  2019-05-21
# 입력완료 -  2019-05-20
# 입력완료 -  2019-05-17
# 입력완료 -  2019-05-16
# 입력완료 -  2019-05-15
# 입력완료 -  2019-05-14
# 입력완료 -  2019-05-13
# 입력완료 -  2019-05-10
# 입력완료 -  2019-05-09
# 입력완료 -  2019-05-08
# 입력완료 -  2019-05-07
# 입력완료 -  2019-05-03
# 입력완료 -  2019-05-02
# 입력완료 -  2019-04-30
# 입력완료 -  2019-04-29
# 입력완료 -  2019-04-26
# 입력완료 -  2019-04-25
# 입력완료 -  2019-04-24
# 입력완료 -  2019-04-23
# 입력완료 -  2019-04-22
# 입력완료 -  2019-04-19
# 입력완료 -  2019-04-18
# 입력완료 -  2019-04-17
# 입력완료 -  2019-04-16
# 입력완료 -  2019-04-15
# 입력완료 -  2019-04-12
# 입력완료 -  2019-04-11
# 입력완료 -  2019-04-10
# 입력완료 -  2019-04-09
# 입력완료 -  2019-04-08
# 입력완료 -  2019-04-05
# 입력완료 -  2019-04-04
# 입력완료 -  2019-04-03
# 입력완료 -  2019-04-02
# 입력완료 -  2019-04-01
# 입력완료 -  2019-03-29
# 입력완료 -  2019-03-28
# 입력완료 -  2019-03-27
# 입력완료 -  2019-03-26
# 입력완료 -  2019-03-25
# 입력완료 -  2019-03-22
# 입력완료 -  2019-03-21
# 입력완료 -  2019-03-20
# 입력완료 -  2019-03-19
# 입력완료 -  2019-03-18
# 입력완료 -  2019-03-15
# 입력완료 -  2019-03-14
# 입력완료 -  2019-03-13
# 입력완료 -  2019-03-12
# 입력완료 -  2019-03-11
# 입력완료 -  2019-03-08
# 입력완료 -  2019-03-07
# 입력완료 -  2019-03-06
# 입력완료 -  2019-03-05
# 입력완료 -  2019-03-04
# 입력완료 -  2019-02-28
# 입력완료 -  2019-02-27
# 입력완료 -  2019-02-26
# 입력완료 -  2019-02-25
# 입력완료 -  2019-02-22
# 입력완료 -  2019-02-21
# 입력완료 -  2019-02-20
# 입력완료 -  2019-02-19
# 입력완료 -  2019-02-18
# 입력완료 -  2019-02-15
# 입력완료 -  2019-02-14
# 입력완료 -  2019-02-13
# 입력완료 -  2019-02-12
# 입력완료 -  2019-02-11
# 입력완료 -  2019-02-08
# 입력완료 -  2019-02-07
# 입력완료 -  2019-02-01
# 입력완료 -  2019-01-31
# 입력완료 -  2019-01-30
# 입력완료 -  2019-01-29
# 입력완료 -  2019-01-28
# 입력완료 -  2019-01-25
# 입력완료 -  2019-01-24
# 입력완료 -  2019-01-23
# 입력완료 -  2019-01-22
# 입력완료 -  2019-01-21
# 입력완료 -  2019-01-18
# 입력완료 -  2019-01-17
# 입력완료 -  2019-01-16
# 입력완료 -  2019-01-15
# 입력완료 -  2019-01-14
# 입력완료 -  2019-01-11
# 입력완료 -  2019-01-10
# 입력완료 -  2019-01-09
# 입력완료 -  2019-01-08
# 입력완료 -  2019-01-07
# 입력완료 -  2019-01-04
# 입력완료 -  2019-01-03
# 입력완료 -  2019-01-02
# 입력완료 -  2018-12-28
# 입력완료 -  2018-12-27
# 입력완료 -  2018-12-26
# 입력완료 -  2018-12-24
# 입력완료 -  2018-12-21
# 입력완료 -  2018-12-20
# 입력완료 -  2018-12-19
# 입력완료 -  2018-12-18
# 입력완료 -  2018-12-17
# 입력완료 -  2018-12-14
# 입력완료 -  2018-12-13
# 입력완료 -  2018-12-12
# 입력완료 -  2018-12-11
# 입력완료 -  2018-12-10
# 입력완료 -  2018-12-07
# 입력완료 -  2018-12-06
# 입력완료 -  2018-12-05
# 입력완료 -  2018-12-04
# 입력완료 -  2018-12-03
# 입력완료 -  2018-11-30
# 입력완료 -  2018-11-29
# 입력완료 -  2018-11-28
# 입력완료 -  2018-11-27
# 입력완료 -  2018-11-26
# 입력완료 -  2018-11-23
# 입력완료 -  2018-11-22
# 입력완료 -  2018-11-21
# 입력완료 -  2018-11-20
# 입력완료 -  2018-11-19
# 입력완료 -  2018-11-16
# 입력완료 -  2018-11-15
# 입력완료 -  2018-11-14
# 입력완료 -  2018-11-13
# 입력완료 -  2018-11-12
# 입력완료 -  2018-11-09
# 입력완료 -  2018-11-08
# 입력완료 -  2018-11-07
# 입력완료 -  2018-11-06
# 입력완료 -  2018-11-05
# 입력완료 -  2018-11-02
# 입력완료 -  2018-11-01
# 입력완료 -  2018-10-31
# 입력완료 -  2018-10-30
# 입력완료 -  2018-10-29
# 입력완료 -  2018-10-26
# 입력완료 -  2018-10-25
# 입력완료 -  2018-10-24
# 입력완료 -  2018-10-23
# 입력완료 -  2018-10-22
# 입력완료 -  2018-10-19
# 입력완료 -  2018-10-18
# 입력완료 -  2018-10-17
# 입력완료 -  2018-10-16
# 입력완료 -  2018-10-15
# 입력완료 -  2018-10-12
# 입력완료 -  2018-10-11
# 입력완료 -  2018-10-10
# 입력완료 -  2018-10-08
# 입력완료 -  2018-10-05
# 입력완료 -  2018-10-04
# 입력완료 -  2018-10-02
# 입력완료 -  2018-10-01
# 입력완료 -  2018-09-28
# 입력완료 -  2018-09-27
# 입력완료 -  2018-09-21
# 입력완료 -  2018-09-20
# 입력완료 -  2018-09-19
# 입력완료 -  2018-09-18
# 입력완료 -  2018-09-17
# 입력완료 -  2018-09-14
# 입력완료 -  2018-09-13
# 입력완료 -  2018-09-12
# 입력완료 -  2018-09-11
# 입력완료 -  2018-09-10
# 입력완료 -  2018-09-07
# 입력완료 -  2018-09-06
# 입력완료 -  2018-09-05
# 입력완료 -  2018-09-04
# 입력완료 -  2018-09-03
# 입력완료 -  2018-08-31
# 입력완료 -  2018-08-30
# 입력완료 -  2018-08-29
# 입력완료 -  2018-08-28
# 입력완료 -  2018-08-27
# 입력완료 -  2018-08-24
# 입력완료 -  2018-08-23
# 입력완료 -  2018-08-22
# 입력완료 -  2018-08-21
# 입력완료 -  2018-08-20
# 입력완료 -  2018-08-17
# 입력완료 -  2018-08-16
# 입력완료 -  2018-08-14
# 입력완료 -  2018-08-13
# 입력완료 -  2018-08-10
# 입력완료 -  2018-08-09
# 입력완료 -  2018-08-08
# 입력완료 -  2018-08-07
# 입력완료 -  2018-08-06
# 입력완료 -  2018-08-03
# 입력완료 -  2018-08-02
# 입력완료 -  2018-08-01
# 입력완료 -  2018-07-31
# 입력완료 -  2018-07-30
# 입력완료 -  2018-07-27
# 입력완료 -  2018-07-26
# 입력완료 -  2018-07-25
# 입력완료 -  2018-07-24
# 입력완료 -  2018-07-23
# 입력완료 -  2018-07-20
# 입력완료 -  2018-07-19
# 입력완료 -  2018-07-18
# 입력완료 -  2018-07-17
# 입력완료 -  2018-07-16
# 입력완료 -  2018-07-13
# 입력완료 -  2018-07-12
# 입력완료 -  2018-07-11
# 입력완료 -  2018-07-10
# 입력완료 -  2018-07-09
# 입력완료 -  2018-07-06
# 입력완료 -  2018-07-05
# 입력완료 -  2018-07-04
# 입력완료 -  2018-07-03
# 입력완료 -  2018-07-02
# 입력완료 -  2018-06-29
# 입력완료 -  2018-06-28
# 입력완료 -  2018-06-27
# 입력완료 -  2018-06-26
# 입력완료 -  2018-06-25
# 입력완료 -  2018-06-22
# 입력완료 -  2018-06-21
# 입력완료 -  2018-06-20
# 입력완료 -  2018-06-19
# 입력완료 -  2018-06-18
# 입력완료 -  2018-06-15
# 입력완료 -  2018-06-14
# 입력완료 -  2018-06-12
# 입력완료 -  2018-06-11
# 입력완료 -  2018-06-08
# 입력완료 -  2018-06-07
# 입력완료 -  2018-06-05
# 입력완료 -  2018-06-04
# 입력완료 -  2018-06-01
# 입력완료 -  2018-05-31
# 입력완료 -  2018-05-30
# 입력완료 -  2018-05-29
# 입력완료 -  2018-05-28
# 입력완료 -  2018-05-25
# 입력완료 -  2018-05-24
# 입력완료 -  2018-05-23
# 입력완료 -  2018-05-21
# 입력완료 -  2018-05-18
# 입력완료 -  2018-05-17
# 입력완료 -  2018-05-16
# 입력완료 -  2018-05-15
# 입력완료 -  2018-05-14
# 입력완료 -  2018-05-11
# 입력완료 -  2018-05-10
# 입력완료 -  2018-05-09
# 입력완료 -  2018-05-08
# 입력완료 -  2018-05-04
# 입력완료 -  2018-05-03
# 입력완료 -  2018-05-02
# 입력완료 -  2018-04-30
# 입력완료 -  2018-04-27
# 입력완료 -  2018-04-26
# 입력완료 -  2018-04-25
# 입력완료 -  2018-04-24
# 입력완료 -  2018-04-23
# 입력완료 -  2018-04-20
# 입력완료 -  2018-04-19
# 입력완료 -  2018-04-18
# 입력완료 -  2018-04-17
# 입력완료 -  2018-04-16
# 입력완료 -  2018-04-13
# 입력완료 -  2018-04-12
# 입력완료 -  2018-04-11
# 입력완료 -  2018-04-10
# 입력완료 -  2018-04-09
# 입력완료 -  2018-04-06
# 입력완료 -  2018-04-05
# 입력완료 -  2018-04-04
# 입력완료 -  2018-04-03
# 입력완료 -  2018-04-02
# 입력완료 -  2018-03-30
# 입력완료 -  2018-03-29
# 입력완료 -  2018-03-28
# 입력완료 -  2018-03-27
# 입력완료 -  2018-03-26
# 입력완료 -  2018-03-23
# 입력완료 -  2018-03-22
# 입력완료 -  2018-03-21
# 입력완료 -  2018-03-20
# 입력완료 -  2018-03-19
# 입력완료 -  2018-03-16
# 입력완료 -  2018-03-15
# 입력완료 -  2018-03-14
# 입력완료 -  2018-03-13
# 입력완료 -  2018-03-12
# 입력완료 -  2018-03-09
# 입력완료 -  2018-03-08
# 입력완료 -  2018-03-07
# 입력완료 -  2018-03-06
# 입력완료 -  2018-03-05
# 입력완료 -  2018-03-02
# 입력완료 -  2018-02-28
# 입력완료 -  2018-02-27
# 입력완료 -  2018-02-26
# 입력완료 -  2018-02-23
# 입력완료 -  2018-02-22
# 입력완료 -  2018-02-21
# 입력완료 -  2018-02-20
# 입력완료 -  2018-02-19
# 입력완료 -  2018-02-14
# 입력완료 -  2018-02-13
# 입력완료 -  2018-02-12
# 입력완료 -  2018-02-09
# 입력완료 -  2018-02-08
# 입력완료 -  2018-02-07
# 입력완료 -  2018-02-06
# 입력완료 -  2018-02-05
# 입력완료 -  2018-02-02
# 입력완료 -  2018-02-01
# 입력완료 -  2018-01-31
# 입력완료 -  2018-01-30
# 입력완료 -  2018-01-29
# 입력완료 -  2018-01-26
# 입력완료 -  2018-01-25
# 입력완료 -  2018-01-24
# 입력완료 -  2018-01-23
# 입력완료 -  2018-01-22
# 입력완료 -  2018-01-19
# 입력완료 -  2018-01-18
# 입력완료 -  2018-01-17
# 입력완료 -  2018-01-16
# 입력완료 -  2018-01-15
# 입력완료 -  2018-01-12
# 입력완료 -  2018-01-11
# 입력완료 -  2018-01-10
# 입력완료 -  2018-01-09
# 입력완료 -  2018-01-08
# 입력완료 -  2018-01-05
# 입력완료 -  2018-01-04
# 입력완료 -  2018-01-03
# 입력완료 -  2018-01-02
# 입력완료 -  2017-12-28
# 입력완료 -  2017-12-27
# 입력완료 -  2017-12-26
# 입력완료 -  2017-12-22
# 입력완료 -  2017-12-21
# 입력완료 -  2017-12-20
# 입력완료 -  2017-12-19
# 입력완료 -  2017-12-18
# 입력완료 -  2017-12-15
# 입력완료 -  2017-12-14
# 입력완료 -  2017-12-13
# 입력완료 -  2017-12-12
# 입력완료 -  2017-12-11
# 입력완료 -  2017-12-08
# 입력완료 -  2017-12-07
# 입력완료 -  2017-12-06
# 입력완료 -  2017-12-05
# 입력완료 -  2017-12-04
# 입력완료 -  2017-12-01
# 입력완료 -  2017-11-30
# 입력완료 -  2017-11-29
# 입력완료 -  2017-11-28
# 입력완료 -  2017-11-27
# 입력완료 -  2017-11-24
# 입력완료 -  2017-11-23
# 입력완료 -  2017-11-22
# 입력완료 -  2017-11-21
# 입력완료 -  2017-11-20
# 입력완료 -  2017-11-17
# 입력완료 -  2017-11-16
# 입력완료 -  2017-11-15
# 입력완료 -  2017-11-14
# 입력완료 -  2017-11-13
# 입력완료 -  2017-11-10
# 입력완료 -  2017-11-09
# 입력완료 -  2017-11-08
# 입력완료 -  2017-11-07
# 입력완료 -  2017-11-06
# 입력완료 -  2017-11-03
# 입력완료 -  2017-11-02
# 입력완료 -  2017-11-01
# 입력완료 -  2017-10-31
# 입력완료 -  2017-10-30
# 입력완료 -  2017-10-27
# 입력완료 -  2017-10-26
# 입력완료 -  2017-10-25
# 입력완료 -  2017-10-24
# 입력완료 -  2017-10-23
# 입력완료 -  2017-10-20
# 입력완료 -  2017-10-19
# 입력완료 -  2017-10-18
# 입력완료 -  2017-10-17
# 입력완료 -  2017-10-16
# 입력완료 -  2017-10-13
# 입력완료 -  2017-10-12
# 입력완료 -  2017-10-11
# 입력완료 -  2017-10-10
# 입력완료 -  2017-09-29
# 입력완료 -  2017-09-28
# 입력완료 -  2017-09-27
# 입력완료 -  2017-09-26
# 입력완료 -  2017-09-25
# 입력완료 -  2017-09-22
# 입력완료 -  2017-09-21
# 입력완료 -  2017-09-20
# 입력완료 -  2017-09-19
# 입력완료 -  2017-09-18
# 입력완료 -  2017-09-15
# 입력완료 -  2017-09-14
# 입력완료 -  2017-09-13
# 입력완료 -  2017-09-12
# 입력완료 -  2017-09-11
# 입력완료 -  2017-09-08
# 입력완료 -  2017-09-07
# 입력완료 -  2017-09-06
# 입력완료 -  2017-09-05
# 입력완료 -  2017-09-04
# 입력완료 -  2017-09-01
# 입력완료 -  2017-08-31
# 입력완료 -  2017-08-30
# 입력완료 -  2017-08-29
# 입력완료 -  2017-08-28
# 입력완료 -  2017-08-25
# 입력완료 -  2017-08-24
# 입력완료 -  2017-08-23
# 입력완료 -  2017-08-22
# 입력완료 -  2017-08-21
# 입력완료 -  2017-08-18
# 입력완료 -  2017-08-17
# 입력완료 -  2017-08-16

# %% [markdown]
# https://blog.daum.net/klangi/12

# %%
def getDB():
    with sqlite3.connect(dbname) as conn:
        cur=conn.cursor()
        sql='select * from stockp where skey>20210301 order by skey asc'
        
        qry=cur.execute(sql)
        desc=[row[0] for row in qry.description]
        data=qry.fetchall()
    return((desc,data))

# %%
res=getDB()
print(res[0])
df=pd.DataFrame(data=res[1],columns=res[0]).set_index('sidx')
df.head()
# Out:
# ['sidx', 'sday', 'sopen', 'shigh', 'slow', 'sclose', 'svol', 'skey']
#             sday   sopen   shigh    slow  sclose    svol      skey
# sidx
# 24    2021-03-02  273500  279000  270500  277500  208163  20210302
# 23    2021-03-03  276000  294000  276000  289500  317893  20210303
# 22    2021-03-04  286500  295000  284000  292000  199955  20210304
# 21    2021-03-05  288000  296000  285000  294500  164541  20210305
# 20    2021-03-08  296000  297000  287000  288000  129915  20210308

# %%
cdf=df[['sday','sclose']].copy()
cdf.head()
# Out:
#             sday  sclose
# sidx
# 24    2021-03-02  277500
# 23    2021-03-03  289500
# 22    2021-03-04  292000
# 21    2021-03-05  294500
# 20    2021-03-08  288000

# %%
from mpl_finance import candlestick_ohlc

# %%
cdf=df.set_index('sday')
candf=cdf[['sopen','shigh','slow','sclose']].astype(int)
candf.head()
# Out:
#              sopen   shigh    slow  sclose
# sday
# 2021-03-02  273500  279000  270500  277500
# 2021-03-03  276000  294000  276000  289500
# 2021-03-04  286500  295000  284000  292000
# 2021-03-05  288000  296000  285000  294500
# 2021-03-08  296000  297000  287000  288000

# %%
import datetime
from matplotlib.dates import date2num
x=np.arange(len(cdf.index))
xs=np.reshape(x,(-1,1))
ohlc=candf.values
canohlc=np.hstack((xs,ohlc))
canohlc
# Out:
# array([[     0, 273500, 279000, 270500, 277500],
#        [     1, 276000, 294000, 276000, 289500],
#        [     2, 286500, 295000, 284000, 292000],
#        [     3, 288000, 296000, 285000, 294500],
#        [     4, 296000, 297000, 287000, 288000],
#        [     5, 291500, 300000, 289000, 291500],
#        [     6, 292000, 297000, 288500, 295000],
#        [     7, 294000, 294500, 282500, 287500],
#        [     8, 291000, 296500, 284000, 287000],
#        [     9, 289000, 291000, 283500, 285500],
#        [    10, 287000, 288500, 282500, 285500],
#        [    11, 289500, 291000, 282000, 284000],
#        [    12, 285500, 287500, 283000, 284000],
#        [    13, 279500, 281000, 275000, 277500],
#        [    14, 278500, 281500, 275000, 281500],
#        [    15, 282500, 283000, 274000, 275000],
#        [    16, 271000, 273500, 269000, 270000],
#        [    17, 269500, 283000, 269000, 280000],
#        [    18, 282000, 285500, 281000, 281500],
#        [    19, 282000, 282000, 276000, 277000],
#        [    20, 276500, 279500, 276000, 279000],
#        [    21, 279000, 281500, 276500, 281000],
#        [    22, 282500, 283000, 277500, 279000],
#        [    23, 278000, 278500, 274000, 274500]])

# %%
from matplotlib.gridspec import GridSpec
fig=plt.figure(figsize=(8,5))
gs=GridSpec(2,1,height_ratios=[3,1])
ax1=fig.add_subplot(gs[0,0]) 
ax2=fig.add_subplot(gs[1,0],sharex=ax1) # x 축 공유
ax1.get_xaxis().set_visible(False) # 가운데 x 축 삭제
candlestick_ohlc(ax1,canohlc,width=0.5, colorup='r', colordown='b')
svol=df['svol'].values # vol
sx=df['sday'].values # x 축
ax2.bar(sx,svol,width=0.6)
ax2.set_ylim(0,1000000)
#ax1.set_xlim(0,20)
#ax1.set_ylim(100000,210000)
ax1.axvline(x=0, color='g', linestyle='--', linewidth=1)
ax1.text(0,298000,'naver contract')
ax1.axvline(x=18, color='y', linestyle='-', linewidth=1)
ax1.text(18,290000,'jaxon issue')
plt.xticks(rotation=45)
plt.show()
