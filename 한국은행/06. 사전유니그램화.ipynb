# %%
from konlpy.tag import Mecab
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c0ff29b7bc2d> in <module>
# ----> 1 from konlpy.tag import Mecab
#
# ModuleNotFoundError: No module named 'konlpy'

# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\Anaconda3\python.exe

# %%
import pandas as pd

# %%
df=pd.read_csv('다합친것수정1.8.csv')
df
# Out:
#        Unnamed: 0  Unnamed: 0.1                                 title  \
# 0               0             0    금융통화위원회 의사록(2005년도 제14차)(2005.7.7)
# 1               1             1  금융통화위원회 의사록(2005년도 제21차)(2005.10.11)
# 2               2             2    금융통화위원회 의사록(2006년도 제2차)(2006.1.12)
# 3               3             3    금융통화위원회 의사록(2006년도 제3차)(2006.1.26)
# 4               4             4     금융통화위원회 의사록(2006년도 제4차)(2006.2.9)
# ...           ...           ...                                   ...
# 84851       80833        105440                     LG카드 증자 극적 타결(종합)
# 84852       80834        105441          한은총재 신년사 "내년 경제 불확실성 여전히 높다"
# 84853       80835        105444               <채권> LG카드 해결에 회사채 금리 하락
# 84854       80836        105445       지표금리 3.28% 마감..올 평균금리 4.09%(마감)
# 84855       80837        105446                         (월가시각)예민해진 시장
#
#                       date                                            content  \
# ...

# %%
df1=pd.read_csv('다합친것.csv')
df1
# Out:
#        Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1        date   콜금리       date2  \
# 0               0             0             0  2021-01-05  0.48  2020-12-08
# 1               1             0             0  2021-01-05  0.48  2020-12-08
# 2               2             0             0  2021-01-05  0.48  2020-12-08
# 3               3             0             0  2021-01-05  0.48  2020-12-08
# 4               4             0             0  2021-01-05  0.48  2020-12-08
# ...           ...           ...           ...         ...   ...         ...
# 49054       49054          2836          2836  2005-01-03  3.27  2004-12-06
# 49055       49055          2836          2836  2005-01-03  3.27  2004-12-06
# 49056       49056          2836          2836  2005-01-03  3.27  2004-12-06
# 49057       49057          2836          2836  2005-01-03  3.27  2004-12-06
# 49058       49058          2836          2836  2005-01-03  3.27  2004-12-06
#
# ...

# %%
df2=pd.read_csv('뉴스의사록채권분석.csv')
df2
# Out:
#        Unnamed: 0        date                                 title  \
# 0               0  2005-08-23    금융통화위원회 의사록(2005년도 제14차)(2005.7.7)
# 1               1  2005-11-29  금융통화위원회 의사록(2005년도 제21차)(2005.10.11)
# 2               2  2006-02-28    금융통화위원회 의사록(2006년도 제2차)(2006.1.12)
# 3               3  2006-03-14    금융통화위원회 의사록(2006년도 제3차)(2006.1.26)
# 4               4  2006-03-28     금융통화위원회 의사록(2006년도 제4차)(2006.2.9)
# ...           ...         ...                                   ...
# 94583        3868  2021-08-04                         항상 열려는 있는 가능성
# 94584        3869  2014-08-04                         총재의 변신은 무죄다?!
# 94585        3870  2007-08-04                                시간차 공격
# 94586        3871  2007-08-04                               돌아온 박스권
# 94587        3872  2001-08-04                     대우증권 월간 채권투자 (4월)
#
#                                                  content  \
# 0      일부 위원은 지난달 연평도 포격 사태 · ｢ ｣ 에도 불구하고 스왑레이트 상승으로 ...
# ...

# %%
df2=pd.read_csv('진짜마지막수정.csv')
df2
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1        date  \
# 0               2             2              19  2021-01-05
# 1               3             3              18  2021-01-05
# 2               4             4              17  2021-01-05
# 3               8             8              12  2021-01-05
# 4              12            12               4  2021-01-05
# ...           ...           ...             ...         ...
# 80833      105440        105440            7347  2004-12-31
# 80834      105441        105441            7346  2004-12-31
# 80835      105444        105444            7343  2004-12-31
# 80836      105445        105445            7342  2004-12-31
# 80837      105446        105446            7361  2004-12-31
#
#                                      title  \
# 0       "현금 줘도 소비 대신 저축만…포스트 코로나 규제완화에 방점"
# 1      "지금 주식시장 과열인가"…증권사 리서치센터장들이 답했다(종합)
# 2            씨티은행, 3개월 만기 2.8% 정기예금 가입 이벤트
# 3         12월 신용대출 11개월만에 줄었지만…전세대출 증가폭 커져
# ...

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1                                 title  \
# 0               0             0    금융통화위원회 의사록(2005년도 제14차)(2005.7.7)
# 1               1             1  금융통화위원회 의사록(2005년도 제21차)(2005.10.11)
# 2               2             2    금융통화위원회 의사록(2006년도 제2차)(2006.1.12)
# 3               3             3    금융통화위원회 의사록(2006년도 제3차)(2006.1.26)
# 4               4             4     금융통화위원회 의사록(2006년도 제4차)(2006.2.9)
# ...           ...           ...                                   ...
# 84851       80833        105440                     LG카드 증자 극적 타결(종합)
# 84852       80834        105441          한은총재 신년사 "내년 경제 불확실성 여전히 높다"
# 84853       80835        105444               <채권> LG카드 해결에 회사채 금리 하락
# 84854       80836        105445       지표금리 3.28% 마감..올 평균금리 4.09%(마감)
# 84855       80837        105446                         (월가시각)예민해진 시장
#
#                       date                                            content  \
# ...

# %%
df2=pd.read_csv('뉴스의사록채권분석.csv')
df2
# Out:
#        Unnamed: 0        date                                 title  \
# 0               0  2005-08-23    금융통화위원회 의사록(2005년도 제14차)(2005.7.7)
# 1               1  2005-11-29  금융통화위원회 의사록(2005년도 제21차)(2005.10.11)
# 2               2  2006-02-28    금융통화위원회 의사록(2006년도 제2차)(2006.1.12)
# 3               3  2006-03-14    금융통화위원회 의사록(2006년도 제3차)(2006.1.26)
# 4               4  2006-03-28     금융통화위원회 의사록(2006년도 제4차)(2006.2.9)
# ...           ...         ...                                   ...
# 94583        3868  2021-08-04                         항상 열려는 있는 가능성
# 94584        3869  2014-08-04                         총재의 변신은 무죄다?!
# 94585        3870  2007-08-04                                시간차 공격
# 94586        3871  2007-08-04                               돌아온 박스권
# 94587        3872  2001-08-04                     대우증권 월간 채권투자 (4월)
#
#                                                  content  \
# 0      일부 위원은 지난달 연평도 포격 사태 · ｢ ｣ 에도 불구하고 스왑레이트 상승으로 ...
# ...

# %%
df2=pd.read_csv('진짜마지막수정.csv')
df2
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1        date  \
# 0               2             2              19  2021-01-05
# 1               3             3              18  2021-01-05
# 2               4             4              17  2021-01-05
# 3               8             8              12  2021-01-05
# 4              12            12               4  2021-01-05
# ...           ...           ...             ...         ...
# 80833      105440        105440            7347  2004-12-31
# 80834      105441        105441            7346  2004-12-31
# 80835      105444        105444            7343  2004-12-31
# 80836      105445        105445            7342  2004-12-31
# 80837      105446        105446            7361  2004-12-31
#
#                                      title  \
# 0       "현금 줘도 소비 대신 저축만…포스트 코로나 규제완화에 방점"
# 1      "지금 주식시장 과열인가"…증권사 리서치센터장들이 답했다(종합)
# 2            씨티은행, 3개월 만기 2.8% 정기예금 가입 이벤트
# 3         12월 신용대출 11개월만에 줄었지만…전세대출 증가폭 커져
# ...

# %%
df2=pd.read_csv('콜금리까지합친것.csv')
df2
# Out:
#        Unnamed: 0  Unnamed: 0_x                                 title  \
# 0               0             0    금융통화위원회 의사록(2005년도 제14차)(2005.7.7)
# 1               1             1  금융통화위원회 의사록(2005년도 제21차)(2005.10.11)
# 2               2             2    금융통화위원회 의사록(2006년도 제2차)(2006.1.12)
# 3               3             3    금융통화위원회 의사록(2006년도 제3차)(2006.1.26)
# 4               4             4     금융통화위원회 의사록(2006년도 제4차)(2006.2.9)
# ...           ...           ...                                   ...
# 84851       84851        105440                     LG카드 증자 극적 타결(종합)
# 84852       84852        105441          한은총재 신년사 "내년 경제 불확실성 여전히 높다"
# 84853       84853        105444               <채권> LG카드 해결에 회사채 금리 하락
# 84854       84854        105445       지표금리 3.28% 마감..올 평균금리 4.09%(마감)
# 84855       84855        105446                         (월가시각)예민해진 시장
#
#              date                                            content  \
# ...

# %%
df2=pd.read_csv('채권분석뉴스의사록.csv')
df2
# Out:
#        Unnamed: 0  Unnamed: 0.1                                 title  \
# 0               0             0    금융통화위원회 의사록(2005년도 제14차)(2005.7.7)
# 1               1             1  금융통화위원회 의사록(2005년도 제21차)(2005.10.11)
# 2               2             2    금융통화위원회 의사록(2006년도 제2차)(2006.1.12)
# 3               3             3    금융통화위원회 의사록(2006년도 제3차)(2006.1.26)
# 4               4             4     금융통화위원회 의사록(2006년도 제4차)(2006.2.9)
# ...           ...           ...                                   ...
# 84851       80833        105440                     LG카드 증자 극적 타결(종합)
# 84852       80834        105441          한은총재 신년사 "내년 경제 불확실성 여전히 높다"
# 84853       80835        105444               <채권> LG카드 해결에 회사채 금리 하락
# 84854       80836        105445       지표금리 3.28% 마감..올 평균금리 4.09%(마감)
# 84855       80837        105446                         (월가시각)예민해진 시장
#
#                       date                                            content  \
# ...

# %%
import pandas as pd
df3=pd.read_csv('극성분석수정본.csv')
df3
# Out:
#       Unnamed: 0  level_0                    index  up_count  down_count  \
# 0              0        2            물가/NNG;안정/NNG     527.0       357.0
# 1              1        6         인플레이션/NNG;압력/NNG     302.0       174.0
# 2              2       20         인플레이션/NNG;억제/NNG     227.0       104.0
# 3              3       23     물가/NNG;상승/NNG;압력/NNG     221.0       128.0
# 4              4       29  유료뉴스/NNG;시장/NNG;플러스/NNG     187.0       117.0
# ...          ...      ...                      ...       ...         ...
# 1191         583     6150            생산/NNG;감축/NNG       3.0        14.0
# 1192         584     6480           수익성/NNG;하락/NNG       3.0        15.0
# 1193         585     6730            심각/NNG;훼손/NNG       3.0        14.0
# 1194         586     6756       비용/NNG;부담/NNG;늘/VV       3.0        13.0
# 1195         587     7162          유동성함정/NNG;빠지/VV       2.0        14.0
#
#       total_count  polar_score polarity
# 0           884.0     1.373467  Hawkish
# ...

# %%
df3=df3.drop(['Unnamed: 0'],axis=1,inplace=True)
df3

# %%
import pandas as pd
df3=pd.read_csv('극성분석수정본.csv')
df3.drop(['Unnamed: 0'],axis=1,inplace=True)
df3.drop(['level_0'],axis=1,inplace=True)
df3
# Out:
#                         index  up_count  down_count  total_count  polar_score  \
# 0               물가/NNG;안정/NNG     527.0       357.0        884.0     1.373467
# 1            인플레이션/NNG;압력/NNG     302.0       174.0        476.0     1.614854
# 2            인플레이션/NNG;억제/NNG     227.0       104.0        331.0     2.030805
# 3        물가/NNG;상승/NNG;압력/NNG     221.0       128.0        349.0     1.606416
# 4     유료뉴스/NNG;시장/NNG;플러스/NNG     187.0       117.0        304.0     1.487070
# ...                       ...       ...         ...          ...          ...
# 1191            생산/NNG;감축/NNG       3.0        14.0         17.0     0.199374
# 1192           수익성/NNG;하락/NNG       3.0        15.0         18.0     0.186083
# 1193            심각/NNG;훼손/NNG       3.0        14.0         17.0     0.199374
# 1194       비용/NNG;부담/NNG;늘/VV       3.0        13.0         16.0     0.214711
# 1195          유동성함정/NNG;빠지/VV       2.0        14.0         16.0     0.132916
#
#      polarity
# 0     Hawkish
# ...

# %%
ngram_list=df3['index'].values.tolist()

# %%
up_count_list=df3['up_count'].values.tolist()
down_count_list=df3['down_count'].values.tolist()
total_count_list=df3['total_count'].values.tolist()
polar_score_list=df3['polar_score'].values.tolist()
polarity_list=df3['polarity'].values.tolist()

# %%
up_count_list[0]
# Out:
# 527.0

# %%
new_df = pd.DataFrame(index=range(0,6), columns=['ngram', 'up_count','down_count','total_count','polar_score','polarity'])
new_df
# Out:
#   ngram up_count down_count total_count polar_score polarity
# 0   NaN      NaN        NaN         NaN         NaN      NaN
# 1   NaN      NaN        NaN         NaN         NaN      NaN
# 2   NaN      NaN        NaN         NaN         NaN      NaN
# 3   NaN      NaN        NaN         NaN         NaN      NaN
# 4   NaN      NaN        NaN         NaN         NaN      NaN
# 5   NaN      NaN        NaN         NaN         NaN      NaN

# %%
new_ngram_list=[]

for i in range(len(ngram_list)):
    text=ngram_list[i].split(';')
    for j in range(len(text)):
        new_data={'ngram':text[j],'up_count':up_count_list[i],'down_count':down_count_list[i],
                'total_count':total_count_list[i],'polar_score':polar_score_list[i],'polarity':polarity_list[i]}
        new_df=new_df.append(new_data,ignore_index=True)

#     for j in text:
#         new_ngram_list.append(j)
#     new_ngram_list()

# %%
len(new_ngram_list2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-14c35ec4165c> in <module>
# ----> 1 len(new_ngram_list2)
#
# NameError: name 'new_ngram_list2' is not defined

# %%
new_df
# Out:
#           ngram  up_count  down_count  total_count  polar_score polarity
# 0           NaN       NaN         NaN          NaN          NaN      NaN
# 1           NaN       NaN         NaN          NaN          NaN      NaN
# 2           NaN       NaN         NaN          NaN          NaN      NaN
# 3           NaN       NaN         NaN          NaN          NaN      NaN
# 4           NaN       NaN         NaN          NaN          NaN      NaN
# ...         ...       ...         ...          ...          ...      ...
# 2767     비용/NNG       3.0        13.0         16.0     0.214711   Dovish
# 2768     부담/NNG       3.0        13.0         16.0     0.214711   Dovish
# 2769       늘/VV       3.0        13.0         16.0     0.214711   Dovish
# 2770  유동성함정/NNG       2.0        14.0         16.0     0.132916   Dovish
# 2771      빠지/VV       2.0        14.0         16.0     0.132916   Dovish
#
# [2772 rows x 6 columns]

# %%
dovish=new_df[new_df['polarity']=='Dovish']
dovish
# Out:
#           ngram  up_count  down_count  total_count  polar_score polarity
# 1424     통화/NNG     161.0       273.0        434.0     0.548705   Dovish
# 1425     완화/NNG     161.0       273.0        434.0     0.548705   Dovish
# 1426     하락/NNG     134.0       167.0        301.0     0.746559   Dovish
# 1427     채권/NNG     134.0       167.0        301.0     0.746559   Dovish
# 1428     가격/NNG     134.0       167.0        301.0     0.746559   Dovish
# ...         ...       ...         ...          ...          ...      ...
# 2767     비용/NNG       3.0        13.0         16.0     0.214711   Dovish
# 2768     부담/NNG       3.0        13.0         16.0     0.214711   Dovish
# 2769       늘/VV       3.0        13.0         16.0     0.214711   Dovish
# 2770  유동성함정/NNG       2.0        14.0         16.0     0.132916   Dovish
# 2771      빠지/VV       2.0        14.0         16.0     0.132916   Dovish
#
# [1348 rows x 6 columns]

# %%
Hawkish=new_df[new_df['polarity']=='Hawkish']
Hawkish
# Out:
#           ngram  up_count  down_count  total_count  polar_score polarity
# 6        물가/NNG     527.0       357.0        884.0     1.373467  Hawkish
# 7        안정/NNG     527.0       357.0        884.0     1.373467  Hawkish
# 8     인플레이션/NNG     302.0       174.0        476.0     1.614854  Hawkish
# 9        압력/NNG     302.0       174.0        476.0     1.614854  Hawkish
# 10    인플레이션/NNG     227.0       104.0        331.0     2.030805  Hawkish
# ...         ...       ...         ...          ...          ...      ...
# 1419     강세/NNG      10.0         6.0         16.0     1.550688  Hawkish
# 1420     안정/NNG      10.0         7.0         17.0     1.329161  Hawkish
# 1421       높/VA      10.0         7.0         17.0     1.329161  Hawkish
# 1422      강하/VA      10.0         6.0         16.0     1.550688  Hawkish
# 1423    모멘텀/NNG      10.0         6.0         16.0     1.550688  Hawkish
#
# [1418 rows x 6 columns]

# %%
Hawkish.drop_duplicates(['ngram'])
# Out:
#           ngram  up_count  down_count  total_count  polar_score polarity
# 6        물가/NNG     527.0       357.0        884.0     1.373467  Hawkish
# 7        안정/NNG     527.0       357.0        884.0     1.373467  Hawkish
# 8     인플레이션/NNG     302.0       174.0        476.0     1.614854  Hawkish
# 9        압력/NNG     302.0       174.0        476.0     1.614854  Hawkish
# 11       억제/NNG     227.0       104.0        331.0     2.030805  Hawkish
# ...         ...       ...         ...          ...          ...      ...
# 1364    증가율/NNG      10.0         6.0         16.0     1.550688  Hawkish
# 1374     탈퇴/NNG      10.0         7.0         17.0     1.329161  Hawkish
# 1400   부채한도/NNG      10.0         7.0         17.0     1.329161  Hawkish
# 1406     아니/VCN      10.0         7.0         17.0     1.329161  Hawkish
# 1418    다원화/NNG      10.0         6.0         16.0     1.550688  Hawkish
#
# [302 rows x 6 columns]

# %%
df5=Hawkish.groupby(['ngram']).sum()
df5.to_csv('ㄷㄷㄷ.csv')


# sub.groupby(sub['노선번호']).mean()  
# 출처: https://data-make.tistory.com/139 [Data Makes Our Future]

# %%
new_hawkish=Hawkish.groupby(['ngram']).sum()
new_hawkish

new_dovish=dovish.groupby(['ngram']).sum()
new_dovish
# Out:
#          up_count  down_count  total_count  polar_score
# ngram
# cd/NNG       39.0        73.0        112.0     2.544483
# cds/NNG      14.0        25.0         39.0     1.054468
# ecb/NNG      11.0        15.0         26.0     0.682303
# fed/NNG     113.0       207.0        320.0     4.980289
# gdp/NNG      87.0       124.0        211.0     2.575346
# ...           ...         ...          ...          ...
# 회피/NNG        7.0         9.0         16.0     0.723654
# 효과/NNG      243.0       502.0        745.0     3.490171
# 후퇴/NNG       25.0        32.0         57.0     0.726885
# 훼손/NNG       15.0        37.0         52.0     0.684807
# 휘발유/NNG      13.0        19.0         32.0     0.636598
#
# [297 rows x 4 columns]

# %%
up_Total = new_hawkish['up_count'].sum()
down_Total =new_hawkish['down_count'].sum()
polarity=[]
for i in range(len(new_hawkish)):
    polarity.append((new_hawkish['up_count'][i]/up_Total)/(new_hawkish['down_count'][i]/down_Total))
new_hawkish['polar_score']=polarity
new_hawkish

polarity=[]
for i in range(len(new_dovish)):
    polarity.append((new_dovish['up_count'][i]/up_Total)/(new_dovish['down_count'][i]/down_Total))
new_dovish['polar_score']=polarity
new_dovish
# Out:
#          up_count  down_count  total_count  polar_score
# ngram
# cd/NNG       39.0        73.0        112.0     0.289946
# cds/NNG      14.0        25.0         39.0     0.303923
# ecb/NNG      11.0        15.0         26.0     0.397995
# fed/NNG     113.0       207.0        320.0     0.296267
# gdp/NNG      87.0       124.0        211.0     0.380779
# ...           ...         ...          ...          ...
# 회피/NNG        7.0         9.0         16.0     0.422115
# 효과/NNG      243.0       502.0        745.0     0.262711
# 후퇴/NNG       25.0        32.0         57.0     0.424000
# 훼손/NNG       15.0        37.0         52.0     0.220022
# 휘발유/NNG      13.0        19.0         32.0     0.371335
#
# [297 rows x 4 columns]

# %%
def Polari(n):
    if n > 1.3:
        a='Hawkish'
    elif n <0.76:
        a='Dovish'
    else:
        a='nothing'
    return a
new_hawkish['polarity'] = new_hawkish'polar_score'].apply(Polari)
new_hawkish = new_hawkish[new_hawkish['polarity']=='Hawkish'].reset_index(drop=True)
df_dicneg = df_newdata[df_newdata['polarity']=='Dovish'].reset_index(drop=True)

# %%
ngram_list=
for i in range(len(nram_list)):
    up_count=
# Out:
# ['물가/NNG',
#  '안정/NNG',
#  '인플레이션/NNG',
#  '압력/NNG',
#  '인플레이션/NNG',
#  '억제/NNG',
#  '물가/NNG',
#  '상승/NNG',
#  '압력/NNG',
#  '유료뉴스/NNG',
#  '시장/NNG',
#  '플러스/NNG',
#  '콜/NNG',
#  '인상/NNG',
#  '하락/NNG',
#  '제한/NNG',
#  '물가/NNG',
#  '불안/NNG',
#  '통화/NNG',
#  '긴축/NNG',
#  '수출/NNG',
#  '호조/NNG',
#  '인상/NNG',
#  '없/VA',
#  '통안채/NNG',
#  '오르/VV',
#  '집값/NNG',
#  '상승/NNG',
#  '인플레이션/NNG',
#  '위험/NNG',
#  '인플레이션/NNG',
#  '상승/NNG',
#  '실적/NNG',
#  '호조/NNG',
#  '부동산/NNG',
#  '거품/NNG',
#  '인상/NNG',
#  '가능성/NNG',
#  '높/VA',
#  '가격/NNG',
#  '안정/NNG',
#  '유가/NNG',
#  '급등/NNG',
#  '서브프라임/NNG',
#  '부실/NNG',
#  '인상/NNG',
#  '부담/NNG',
#  '인상/NNG',
#  '효과/NNG',
#  '예상/NNG',
#  '하회/NNG',
#  '높/VA',
#  '인상/NNG',
#  '가격/NNG',
#  '인상/NNG',
#  '대출/NNG',
#  '부담/NNG',
#  '하방/NNG',
#  '경직/NNG',
#  '부동산/NNG',
#  '안정/NNG',
#  '물가/NNG',
#  '압력/NNG',
#  '국고채/NNG',
#  '낮/VA',
#  '회복/NNG',
#  '둔화/NNG',
#  '유동성/NNG',
#  '흡수/NNG',
#  '주택시장/NNG',
#  '침체/NNG',
#  '개선/NNG',
#  '추세/NNG',
#  '물가/NNG',
#  '잡/VV',
# ...

# %%
new_df=pd.concat([Hawkish,dovish]).reset_index()
new_df.to_csv('극성사전한개로분류.csv')

# %%
new_df
# Out:
#       index      ngram  up_count  down_count  total_count  polar_score  \
# 0         6     물가/NNG     527.0       357.0        884.0     1.373467
# 1         7     안정/NNG     527.0       357.0        884.0     1.373467
# 2         8  인플레이션/NNG     302.0       174.0        476.0     1.614854
# 3         9     압력/NNG     302.0       174.0        476.0     1.614854
# 4        10  인플레이션/NNG     227.0       104.0        331.0     2.030805
# ...     ...        ...       ...         ...          ...          ...
# 2761   2767     비용/NNG       3.0        13.0         16.0     0.214711
# 2762   2768     부담/NNG       3.0        13.0         16.0     0.214711
# 2763   2769       늘/VV       3.0        13.0         16.0     0.214711
# 2764   2770  유동성함정/NNG       2.0        14.0         16.0     0.132916
# 2765   2771      빠지/VV       2.0        14.0         16.0     0.132916
#
#      polarity
# 0     Hawkish
# 1     Hawkish
# 2     Hawkish
# 3     Hawkish
# 4     Hawkish
# ...       ...
# ...

# %%
up_count_list[0]
# Out:
# 161.0

# %%
new_df
# Out:
# {'ngram': '빠지/VV',
#  'up_count': 2.0,
#  'down_count_list': 14.0,
#  'total_count_list': 16.0,
#  'polar_score': 0.13291611386267166,
#  'polarity': 'Dovish'}
