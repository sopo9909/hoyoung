# %% [markdown]
# # 이동평균선
#  * 일정 기간동안의 평균을 이동하면서 계산하여 이은 선
#  * 5,20,60,120 이 일반적인 기준
#  * 장단기 크로스 포인트 기반의 투자 기법
#  * 단기 라인이 장기 라인을 위에서 아래로 뚫었을때 : 매도 타이밍
#  * 단기 라인이 장기 라인을 아래서 위로 뚫었을때: 매수 타이밍
#  * ? 도대체 몇일 선이 단기라인이고 장기라인인 것인가?

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup as bsp
import matplotlib as mpl
import matplotlib.pyplot as plt
import sqlite3

# %%
code=271560
pgno=2
url='https://finance.naver.com/item/sise_day.nhn?code={0}&page={1}'
tgurl=url.format(code,pgno)
tgurl
# Out:
# 'https://finance.naver.com/item/sise_day.nhn?code=271560&page=2'

# %%
def getDB():
    dbname='stockdata.db'
    with sqlite3.connect(dbname) as conn:
        cur=conn.cursor()
        sql='select * from stockp order by skey asc'
        qry=cur.execute(sql)
        desc=[row[0] for row in qry.description]
        data=qry.fetchall()
    return((desc,data))

# %%
res=getDB()
res[0]
# Out:
# ['sidx', 'skey', 'sday', 'sopen', 'shigh', 'slow', 'sclose', 'svol']

# %%
df=pd.DataFrame(data=res[1],columns=res[0]).set_index('sidx')
df.head()
# Out:
#           skey        sday  sopen  shigh   slow  sclose     svol
# sidx
# 895   20170707  2017-07-07  87100  89700  75700   82300  1619864
# 894   20170710  2017-07-10  82300  88000  81000   88000   840451
# 893   20170711  2017-07-11  88000  88000  82700   82800   422303
# 892   20170712  2017-07-12  83700  84600  80000   83500   238407
# 891   20170713  2017-07-13  83400  84000  80800   81600   218138

# %%
df.plot.line(x='sday',y='sclose')
# Out:
# <AxesSubplot:xlabel='sday'>

# %% [raw]
# cdf=df[['sday','sclose']].copy()
# cdf.head()

# %%
def mvline(src=[],mday=5):
    mvdata=[0 for i in range(mday-1)]
    mvdata
    tot =len(src)
    for i in range(tot-mday+1):
        mvm=np.mean(cdf['sclose'][i:mday+i])
        mvdata.append(mvm)
    return (mvdata)

# %%
cdf['mvshort']=mvline(cdf['sclose'],5)
cdf['mvlong']=mvline(cdf['sclose'],20)

# %%
cdf.head(20)
# Out:
#             sday  sclose     mov5  mvshort   mvlong
# sidx
# 895   2017-07-07   82300      0.0      0.0      0.0
# 894   2017-07-10   88000      0.0      0.0      0.0
# 893   2017-07-11   82800      0.0      0.0      0.0
# 892   2017-07-12   83500      0.0      0.0      0.0
# 891   2017-07-13   81600  83640.0  83640.0      0.0
# 890   2017-07-14   81000  83380.0  83380.0      0.0
# 889   2017-07-17   82200  82220.0  82220.0      0.0
# 888   2017-07-18   83300  82320.0  82320.0      0.0
# 887   2017-07-19   84600  82540.0  82540.0      0.0
# 886   2017-07-20   80500  82320.0  82320.0      0.0
# 885   2017-07-21   81200  82360.0  82360.0      0.0
# 884   2017-07-24   83000  82520.0  82520.0      0.0
# 883   2017-07-25   83300  82520.0  82520.0      0.0
# 882   2017-07-26   85100  82620.0  82620.0      0.0
# 881   2017-07-27   84200  83360.0  83360.0      0.0
# 880   2017-07-28   84800  84080.0  84080.0      0.0
# 879   2017-07-31   82100  83900.0  83900.0      0.0
# 878   2017-08-01   83500  83940.0  83940.0      0.0
# 877   2017-08-02   82900  83500.0  83500.0      0.0
# 876   2017-08-03   83700  83400.0  83400.0  83180.0

# %%
cdf['shortpos']=np.where(cdf['mvshort']>cdf['mvlong'],1,-1) * np.where(cdf['mvlong']==0,0,1)
redf=cdf.set_index('sday')
redf.head()
# Out:
#             sclose     mov5  mvshort  mvlong  shortpos
# sday
# 2017-07-07   82300      0.0      0.0     0.0         0
# 2017-07-10   88000      0.0      0.0     0.0         0
# 2017-07-11   82800      0.0      0.0     0.0         0
# 2017-07-12   83500      0.0      0.0     0.0         0
# 2017-07-13   81600  83640.0  83640.0     0.0         0

# %%
redf['preshortpos']=redf['shortpos'].shift(1)
redf.tail(20)
# Out:
#             sclose      mov5   mvshort    mvlong  shortpos  preshortpos
# sday
# 2021-01-25  126000  121700.0  121700.0  122700.0        -1         -1.0
# 2021-01-26  123000  122200.0  122200.0  122600.0        -1         -1.0
# 2021-01-27  123500  122900.0  122900.0  122625.0         1         -1.0
# 2021-01-28  123000  123400.0  123400.0  122650.0         1          1.0
# 2021-01-29  120000  123100.0  123100.0  122450.0         1          1.0
# 2021-02-01  123000  122500.0  122500.0  122450.0         1          1.0
# 2021-02-02  125500  123000.0  123000.0  122525.0         1          1.0
# 2021-02-03  122500  122800.0  122800.0  122425.0         1          1.0
# 2021-02-04  118500  121900.0  121900.0  122175.0        -1          1.0
# 2021-02-05  121500  122200.0  122200.0  121875.0         1         -1.0
# 2021-02-08  122000  122000.0  122000.0  121850.0         1          1.0
# 2021-02-09  126500  122200.0  122200.0  122150.0         1          1.0
# 2021-02-10  125000  122700.0  122700.0  122300.0         1          1.0
# 2021-02-15  123500  123700.0  123700.0  122300.0         1          1.0
# 2021-02-16  131500  125700.0  125700.0  122800.0         1          1.0
# 2021-02-17  139000  129100.0  129100.0  123825.0         1          1.0
# 2021-02-18  135500  130900.0  130900.0  124575.0         1          1.0
# 2021-02-19  136000  133100.0  133100.0  125375.0         1          1.0
# 2021-02-22  131000  134600.0  134600.0  125900.0         1          1.0
# 2021-02-23  133500  135000.0  135000.0  126500.0         1          1.0

# %%
redf[['mvshort','mvlong']].plot()
plt.xlim(30,60)
plt.ylim(80000,110000)
plt.show()

# %%
def finprs(df):
    fdf=df.copy()
    precre=0 # 이전 주식 잔고
    predeb=1000000 # 이전 통장 잔고
    prestock=0
    for idx,row in fdf.iterrows():
         # 살수 있는 주식의 갯수
        #단기물 곡선이 하위 포지션에 있다가 장기물 곡선을 크로스 하였다=> 주가 상승 압력이 시작됬다
        # 상승할것으로 보여지니 매수한다.
        if (row.loc['shortpos']==1 and row.loc['shortpos']*row.loc['preshortpos']<0):
            canbuy=predeb//row.loc['sclose']
            if(canbuy>0):
                #산다
                cre=precre+canbuy*row.loc['sclose']
                deb=predeb-canbuy*row.loc['sclose']
                instock=canbuy
            else:# 돈없어서 아무일 없다
                instock=prestock
                cre=precre
                deb=predeb                
        # 단기물 곡선이 상위포지션에 있다가 장기물 곡선을 크로스했다--> 주가의 하방압력이 시작됬다.
        # 하락할것으로 보여지니 매도한다.
        elif (row.loc['shortpos']==-1 and row.loc['shortpos']*row.loc['preshortpos']<0):
            cre=0
            deb=predeb+row.loc['sclose']*prestock
            instock=0
            # sellpos:1 prestock:1,sellpos:-1 prestock:0, no debt
        else:# 조건이 안맞아서 아무일 없다.
            instock=prestock
            cre=precre
            deb=predeb
        fdf.loc[idx,'hasstock']=instock
        fdf.loc[idx,'debt']=deb
        fdf.loc[idx,'credit']=cre
        prestock=instock
        precre=cre
        predeb=deb
    return fdf

# %%
rdf=finprs(redf)
rdf.head(30)
# Out:
#             sclose     mov5  mvshort   mvlong  shortpos  preshortpos  \
# sday
# 2017-07-07   82300      0.0      0.0      0.0         0          NaN
# 2017-07-10   88000      0.0      0.0      0.0         0          0.0
# 2017-07-11   82800      0.0      0.0      0.0         0          0.0
# 2017-07-12   83500      0.0      0.0      0.0         0          0.0
# 2017-07-13   81600  83640.0  83640.0      0.0         0          0.0
# 2017-07-14   81000  83380.0  83380.0      0.0         0          0.0
# 2017-07-17   82200  82220.0  82220.0      0.0         0          0.0
# 2017-07-18   83300  82320.0  82320.0      0.0         0          0.0
# 2017-07-19   84600  82540.0  82540.0      0.0         0          0.0
# 2017-07-20   80500  82320.0  82320.0      0.0         0          0.0
# 2017-07-21   81200  82360.0  82360.0      0.0         0          0.0
# 2017-07-24   83000  82520.0  82520.0      0.0         0          0.0
# 2017-07-25   83300  82520.0  82520.0      0.0         0          0.0
# 2017-07-26   85100  82620.0  82620.0      0.0         0          0.0
# 2017-07-27   84200  83360.0  83360.0      0.0         0          0.0
# 2017-07-28   84800  84080.0  84080.0      0.0         0          0.0
# 2017-07-31   82100  83900.0  83900.0      0.0         0          0.0
# 2017-08-01   83500  83940.0  83940.0      0.0         0          0.0
# 2017-08-02   82900  83500.0  83500.0      0.0         0          0.0
# 2017-08-03   83700  83400.0  83400.0  83180.0         1          0.0
# 2017-08-04   85300  83500.0  83500.0  83330.0         1          1.0
# 2017-08-07   85600  84200.0  84200.0  83210.0         1          1.0
# 2017-08-08   85000  84500.0  84500.0  83320.0         1          1.0
# 2017-08-09   85600  85040.0  85040.0  83425.0         1          1.0
# 2017-08-10   85300  85360.0  85360.0  83610.0         1          1.0
# 2017-08-11   86500  85600.0  85600.0  83885.0         1          1.0
# 2017-08-14   89400  86360.0  86360.0  84245.0         1          1.0
# 2017-08-16   95300  88420.0  88420.0  84845.0         1          1.0
# 2017-08-17   92200  89740.0  89740.0  85225.0         1          1.0
# 2017-08-18   95400  91760.0  91760.0  85970.0         1          1.0
#
#             hasstock       debt  credit
# sday
# 2017-07-07       0.0  1000000.0     0.0
# 2017-07-10       0.0  1000000.0     0.0
# 2017-07-11       0.0  1000000.0     0.0
# 2017-07-12       0.0  1000000.0     0.0
# 2017-07-13       0.0  1000000.0     0.0
# 2017-07-14       0.0  1000000.0     0.0
# 2017-07-17       0.0  1000000.0     0.0
# 2017-07-18       0.0  1000000.0     0.0
# 2017-07-19       0.0  1000000.0     0.0
# 2017-07-20       0.0  1000000.0     0.0
# 2017-07-21       0.0  1000000.0     0.0
# 2017-07-24       0.0  1000000.0     0.0
# 2017-07-25       0.0  1000000.0     0.0
# 2017-07-26       0.0  1000000.0     0.0
# 2017-07-27       0.0  1000000.0     0.0
# 2017-07-28       0.0  1000000.0     0.0
# 2017-07-31       0.0  1000000.0     0.0
# 2017-08-01       0.0  1000000.0     0.0
# 2017-08-02       0.0  1000000.0     0.0
# 2017-08-03       0.0  1000000.0     0.0
# 2017-08-04       0.0  1000000.0     0.0
# 2017-08-07       0.0  1000000.0     0.0
# 2017-08-08       0.0  1000000.0     0.0
# 2017-08-09       0.0  1000000.0     0.0
# 2017-08-10       0.0  1000000.0     0.0
# 2017-08-11       0.0  1000000.0     0.0
# 2017-08-14       0.0  1000000.0     0.0
# 2017-08-16       0.0  1000000.0     0.0
# 2017-08-17       0.0  1000000.0     0.0
# 2017-08-18       0.0  1000000.0     0.0

# %%
rdf['totval']=rdf['debt']+rdf['credit']
rdf.tail()
# Out:
#             sclose      mov5   mvshort    mvlong  shortpos  preshortpos  \
# sday
# 2021-02-17  139000  129100.0  129100.0  123825.0         1          1.0
# 2021-02-18  135500  130900.0  130900.0  124575.0         1          1.0
# 2021-02-19  136000  133100.0  133100.0  125375.0         1          1.0
# 2021-02-22  131000  134600.0  134600.0  125900.0         1          1.0
# 2021-02-23  133500  135000.0  135000.0  126500.0         1          1.0
#
#             hasstock      debt    credit     totval
# sday
# 2021-02-17       8.0  110100.0  972000.0  1082100.0
# 2021-02-18       8.0  110100.0  972000.0  1082100.0
# 2021-02-19       8.0  110100.0  972000.0  1082100.0
# 2021-02-22       8.0  110100.0  972000.0  1082100.0
# 2021-02-23       8.0  110100.0  972000.0  1082100.0

# %%
ax1=rdf['totval'].plot()
ax1.set_ylabel('debit')
ax2 = rdf['sclose'].plot(secondary_y=True, color='r')
ax2.set_ylabel('stock price')
plt.show()
